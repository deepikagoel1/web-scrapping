# %%
import requests

url = "https://flight-data4.p.rapidapi.com/get_flight_info"

querystring = {"flight":"SQ655"}

headers = {
    'x-rapidapi-key': "b50227ebe2msh5ca575a8bfbfb94p136822jsn75ca3338873a",
    'x-rapidapi-host': "flight-data4.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"SQ655":null}

# %%
import requests

url = "https://iata-and-icao-codes.p.rapidapi.com/airlines"

headers = {
    'x-rapidapi-key': "b50227ebe2msh5ca575a8bfbfb94p136822jsn75ca3338873a",
    'x-rapidapi-host': "iata-and-icao-codes.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# [
#   {"iata_code":"0V","name":"VASCO","icao_code":"VFC"},
#   {"iata_code":"1X","name":"Branson Air Express","icao_code":null},
#   {"iata_code":"2G","name":"Angara Airlines","icao_code":"AGU"},
#   {"iata_code":"2I","name":"Star Peru","icao_code":"SRU"},
#   {"iata_code":"2J","name":"Air Burkina","icao_code":"VBW"},
#   {"iata_code":"2K","name":"Avianca","icao_code":"GLG"},
#   {"iata_code":"2M","name":"Maya Island Air","icao_code":"MYD"},
#   {"iata_code":"2B","name":"Albawings","icao_code":"AWT"},
#   {"iata_code":"0B","name":"Blue Air","icao_code":"BMS"},
#   {"iata_code":"2L","name":"Helvetic Airways","icao_code":"OAW"},
#   {"iata_code":"2U","name":"Sun d'Or Airlines","icao_code":"ERO"},
#   {"iata_code":"2Z","name":"Passaredo Linhas Aéreas","icao_code":"PTB"},
#   {"iata_code":"3B","name":"Binter Cabo Verde","icao_code":"NTB"},
#   {"iata_code":"3C","name":"Air Chathams","icao_code":"CVA"},
#   {"iata_code":"3E","name":"Air Choice One","icao_code":"WBR"},
# ...

# %%
import requests

url = "https://google-flights-search.p.rapidapi.com/search"

querystring = {"departure_airport_code":"SFO","arrival_airport_code":"LAX","departure_date":"2021-04-01"}

headers = {
    'x-rapidapi-key': "b50227ebe2msh5ca575a8bfbfb94p136822jsn75ca3338873a",
    'x-rapidapi-host': "google-flights-search.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"flights": null, "date": "2021-04-04T18:17:12.186396", "status": "success"}

# %%
import requests

url = "https://flight-data4.p.rapidapi.com/get_all_flights"

headers = {
    'x-rapidapi-key': "b50227ebe2msh5ca575a8bfbfb94p136822jsn75ca3338873a",
    'x-rapidapi-host': "flight-data4.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {"message":"This endpoint is disabled for your subscription"}

# %%
import requests

url = "https://priceline-com.p.rapidapi.com/flights/LAX/SFO/2021-02-17"

querystring = {"adults":"1"}

headers = {
    'x-rapidapi-key': "b50227ebe2msh5ca575a8bfbfb94p136822jsn75ca3338873a",
    'x-rapidapi-host': "priceline-com.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#   <meta charset="utf-8">
#   <meta content="width=300, initial-scale=1" name="viewport">
#   <meta name="google-site-verification" content="LrdTUW9psUAMbh4Ia074-BPEVmcpBxF6Gwf0MSgQXZs">
#   <title>Sign in - Google Accounts</title>
#   <style>
#   @font-face {
#   font-family: 'Open Sans';
#   font-style: normal;
#   font-weight: 300;
#   src: url(//fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN_r8OUuhs.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Open Sans';
#   font-style: normal;
#   font-weight: 400;
#   src: url(//fonts.gstatic.com/s/opensans/v15/mem8YaGs126MiZpBA-UFVZ0e.ttf) format('truetype');
# }
#   </style>
#   <style>
#   h1, h2 {
#   -webkit-animation-duration: 0.1s;
#   -webkit-animation-name: fontfix;
#   -webkit-animation-iteration-count: 1;
#   -webkit-animation-timing-function: linear;
#   -webkit-animation-delay: 0;
#   }
#   @-webkit-keyframes fontfix {
#   from {
#   opacity: 1;
#   }
#   to {
# ...

# %%
import requests

url = "https://flight10.p.rapidapi.comhttps//flightslogic.com/about.php"

headers = {
    'authorization': "Basic Z29lbGQ5OTExQGdtYWlsLmNvbTpMaWZlQDEyMw==",
    'x-rapidapi-key': "b50227ebe2msh5ca575a8bfbfb94p136822jsn75ca3338873a",
    'x-rapidapi-host': "flight10.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#
# ~/anaconda3/lib/python3.8/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     919         af, socktype, proto, canonname, sa = res
#
# ...

# %%
import requests

url = "https://flight-data4.p.rapidapi.com/get_flight_info"

querystring = {"flight":"SQ655"}

headers = {
    'x-rapidapi-key': "b50227ebe2msh5ca575a8bfbfb94p136822jsn75ca3338873a",
    'x-rapidapi-host': "flight-data4.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"SQ655":null}

# %%
import requests

url = "https://flight-data4.p.rapidapi.com/get_airline_flights"

querystring = {"airline":"SIA"}

headers = {
    'x-rapidapi-key': "b50227ebe2msh5ca575a8bfbfb94p136822jsn75ca3338873a",
    'x-rapidapi-host': "flight-data4.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# [
#     {
#         "airline": "SIA",
#         "altitude": 43004,
#         "arrival": "SIN",
#         "arrival_position": [
#             1.35019,
#             103.994
#         ],
#         "departure": "SFO",
#         "departure_position": [
#             37.619,
#             -122.375
#         ],
#         "flight": "SQ33",
#         "groundspeed": 472,
#         "heading": 228,
#         "latitude": 10.7589,
#         "longitude": 118.254,
#         "registration": "9V-SGD",
#         "source": "SATE",
#         "station": "ADS-C",
#         "timestamp": 1617562192195,
#         "type": "A359",
#         "verticalspeed": -16
#     },
#     {
#         "airline": "SIA",
#         "altitude": 42804,
#         "arrival": "SIN",
#         "arrival_position": [
#             1.35019,
#             103.994
#         ],
#         "departure": "LAX",
#         "departure_position": [
#             33.9425,
#             -118.408
#         ],
#         "flight": "SQ37",
# ...

# %%
import requests

url = "https://priceline-com.p.rapidapi.com/flights/SFO/LAX/2021-04-15/2021-05-31"

querystring = {"adults":"1"}

headers = {
    'x-rapidapi-key': "b50227ebe2msh5ca575a8bfbfb94p136822jsn75ca3338873a",
    'x-rapidapi-host': "priceline-com.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#   <meta charset="utf-8">
#   <meta content="width=300, initial-scale=1" name="viewport">
#   <meta name="google-site-verification" content="LrdTUW9psUAMbh4Ia074-BPEVmcpBxF6Gwf0MSgQXZs">
#   <title>Sign in - Google Accounts</title>
#   <style>
#   @font-face {
#   font-family: 'Open Sans';
#   font-style: normal;
#   font-weight: 300;
#   src: url(//fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN_r8OUuhs.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Open Sans';
#   font-style: normal;
#   font-weight: 400;
#   src: url(//fonts.gstatic.com/s/opensans/v15/mem8YaGs126MiZpBA-UFVZ0e.ttf) format('truetype');
# }
#   </style>
#   <style>
#   h1, h2 {
#   -webkit-animation-duration: 0.1s;
#   -webkit-animation-name: fontfix;
#   -webkit-animation-iteration-count: 1;
#   -webkit-animation-timing-function: linear;
#   -webkit-animation-delay: 0;
#   }
#   @-webkit-keyframes fontfix {
#   from {
#   opacity: 1;
#   }
#   to {
# ...
