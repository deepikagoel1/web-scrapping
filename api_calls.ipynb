# %%
import requests

url = "https://flight-data4.p.rapidapi.com/get_flight_info"

querystring = {"flight":"SQ655"}

headers = {
    'x-rapidapi-key': "b50227ebe2msh5ca575a8bfbfb94p136822jsn75ca3338873a",
    'x-rapidapi-host': "flight-data4.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"SQ655":null}

# %%
import requests

url = "https://iata-and-icao-codes.p.rapidapi.com/airlines"

headers = {
    'x-rapidapi-key': "b50227ebe2msh5ca575a8bfbfb94p136822jsn75ca3338873a",
    'x-rapidapi-host': "iata-and-icao-codes.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# [
#   {"iata_code":"0V","name":"VASCO","icao_code":"VFC"},
#   {"iata_code":"1X","name":"Branson Air Express","icao_code":null},
#   {"iata_code":"2G","name":"Angara Airlines","icao_code":"AGU"},
#   {"iata_code":"2I","name":"Star Peru","icao_code":"SRU"},
#   {"iata_code":"2J","name":"Air Burkina","icao_code":"VBW"},
#   {"iata_code":"2K","name":"Avianca","icao_code":"GLG"},
#   {"iata_code":"2M","name":"Maya Island Air","icao_code":"MYD"},
#   {"iata_code":"2B","name":"Albawings","icao_code":"AWT"},
#   {"iata_code":"0B","name":"Blue Air","icao_code":"BMS"},
#   {"iata_code":"2L","name":"Helvetic Airways","icao_code":"OAW"},
#   {"iata_code":"2U","name":"Sun d'Or Airlines","icao_code":"ERO"},
#   {"iata_code":"2Z","name":"Passaredo Linhas Aéreas","icao_code":"PTB"},
#   {"iata_code":"3B","name":"Binter Cabo Verde","icao_code":"NTB"},
#   {"iata_code":"3C","name":"Air Chathams","icao_code":"CVA"},
#   {"iata_code":"3E","name":"Air Choice One","icao_code":"WBR"},
# ...

# %%
import requests

url = "https://google-flights-search.p.rapidapi.com/search"

querystring = {"departure_airport_code":"SFO","arrival_airport_code":"LAX","departure_date":"2021-04-01"}

headers = {
    'x-rapidapi-key': "b50227ebe2msh5ca575a8bfbfb94p136822jsn75ca3338873a",
    'x-rapidapi-host': "google-flights-search.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"flights": null, "date": "2021-04-05T08:51:33.666599", "status": "success"}

# %%
import requests

url = "https://flight-data4.p.rapidapi.com/get_all_flights"

headers = {
    'x-rapidapi-key': "b50227ebe2msh5ca575a8bfbfb94p136822jsn75ca3338873a",
    'x-rapidapi-host': "flight-data4.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {"message":"This endpoint is disabled for your subscription"}

# %%
import requests

url = "https://priceline-com.p.rapidapi.com/flights/LAX/SFO/2021-02-17"

querystring = {"adults":"1"}

headers = {
    'x-rapidapi-key': "b50227ebe2msh5ca575a8bfbfb94p136822jsn75ca3338873a",
    'x-rapidapi-host': "priceline-com.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#   <meta charset="utf-8">
#   <meta content="width=300, initial-scale=1" name="viewport">
#   <meta name="google-site-verification" content="LrdTUW9psUAMbh4Ia074-BPEVmcpBxF6Gwf0MSgQXZs">
#   <title>Sign in - Google Accounts</title>
#   <style>
#   @font-face {
#   font-family: 'Open Sans';
#   font-style: normal;
#   font-weight: 300;
#   src: url(//fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN_r8OUuhs.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Open Sans';
#   font-style: normal;
#   font-weight: 400;
#   src: url(//fonts.gstatic.com/s/opensans/v15/mem8YaGs126MiZpBA-UFVZ0e.ttf) format('truetype');
# }
#   </style>
#   <style>
#   h1, h2 {
#   -webkit-animation-duration: 0.1s;
#   -webkit-animation-name: fontfix;
#   -webkit-animation-iteration-count: 1;
#   -webkit-animation-timing-function: linear;
#   -webkit-animation-delay: 0;
#   }
#   @-webkit-keyframes fontfix {
#   from {
#   opacity: 1;
#   }
#   to {
# ...

# %%
import requests

url = "https://flight-data4.p.rapidapi.com/get_flight_info"

querystring = {"flight":"SQ655"}

headers = {
    'x-rapidapi-key': "b50227ebe2msh5ca575a8bfbfb94p136822jsn75ca3338873a",
    'x-rapidapi-host': "flight-data4.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"SQ655":null}

# %%
import requests

url = "https://flight-data4.p.rapidapi.com/get_airline_flights"

querystring = {"airline":"SIA"}

headers = {
    'x-rapidapi-key': "b50227ebe2msh5ca575a8bfbfb94p136822jsn75ca3338873a",
    'x-rapidapi-host': "flight-data4.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# [
#     {
#         "airline": "SIA",
#         "altitude": 40000,
#         "arrival": "LHR",
#         "arrival_position": [
#             51.4706,
#             -0.461941
#         ],
#         "departure": "SIN",
#         "departure_position": [
#             1.35019,
#             103.994
#         ],
#         "flight": "SQ308",
#         "groundspeed": 450,
#         "heading": 260,
#         "latitude": 54.30139,
#         "longitude": 24.55105,
#         "registration": "9V-SMU",
#         "source": "ADSB",
#         "station": "EXTRPI005716",
#         "timestamp": 1617625431897,
#         "type": "A359",
#         "verticalspeed": ""
#     },
#     {
#         "airline": "SIA",
#         "altitude": 41000,
#         "arrival": "SIN",
#         "arrival_position": [
#             1.35019,
#             103.994
#         ],
#         "departure": "JFK",
#         "departure_position": [
#             40.6398,
#             -73.7789
#         ],
#         "flight": "SQ23",
# ...

# %%
import requests

url = "https://priceline-com.p.rapidapi.com/flights/SFO/LAX/2021-04-15/2021-05-31"

querystring = {"adults":"1"}

headers = {
    'x-rapidapi-key': "b50227ebe2msh5ca575a8bfbfb94p136822jsn75ca3338873a",
    'x-rapidapi-host': "priceline-com.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#   <meta charset="utf-8">
#   <meta content="width=300, initial-scale=1" name="viewport">
#   <meta name="google-site-verification" content="LrdTUW9psUAMbh4Ia074-BPEVmcpBxF6Gwf0MSgQXZs">
#   <title>Sign in - Google Accounts</title>
#   <style>
#   @font-face {
#   font-family: 'Open Sans';
#   font-style: normal;
#   font-weight: 300;
#   src: url(//fonts.gstatic.com/s/opensans/v15/mem5YaGs126MiZpBA-UN_r8OUuhs.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Open Sans';
#   font-style: normal;
#   font-weight: 400;
#   src: url(//fonts.gstatic.com/s/opensans/v15/mem8YaGs126MiZpBA-UFVZ0e.ttf) format('truetype');
# }
#   </style>
#   <style>
#   h1, h2 {
#   -webkit-animation-duration: 0.1s;
#   -webkit-animation-name: fontfix;
#   -webkit-animation-iteration-count: 1;
#   -webkit-animation-timing-function: linear;
#   -webkit-animation-delay: 0;
#   }
#   @-webkit-keyframes fontfix {
#   from {
#   opacity: 1;
#   }
#   to {
# ...

# %%
import requests
url = "http://api.travelpayouts.com/v1/prices/cheap?origin=NYC&destination=SFO&depart_date=2021-04&return_date=2021-06&token=ed625cf473b6ec639bfc3083a9d0d414"
response = requests.request("GET", url)

print(response.text)
# Out:
# {"success":true,"data":{"SFO":{"0":{"price":18813,"airline":"UA","flight_number":741,"departure_at":"2021-06-05T21:00:00Z","return_at":"2021-06-21T02:00:00Z","expires_at":"2021-04-07T14:58:30Z"},"1":{"price":18574,"airline":"DL","flight_number":1447,"departure_at":"2021-05-24T15:12:00Z","return_at":"2021-06-01T01:15:00Z","expires_at":"2021-04-06T06:05:18Z"},"2":{"price":19859,"airline":"UA","flight_number":343,"departure_at":"2021-06-04T11:00:00Z","return_at":"2021-06-12T15:00:00Z","expires_at":"2021-04-06T06:54:49Z"},"3":{"price":25377,"airline":"UA","flight_number":2006,"departure_at":"2021-05-24T22:30:00Z","return_at":"2021-06-02T00:33:00Z","expires_at":"2021-04-06T06:05:18Z"}}},"error":"","currency":"rub"}

# %% [markdown]
# # Price Map: prices

# %%
import requests
import json
import csv

url="http://map.aviasales.ru/prices.json?origin_iata=NYC&period=2021-04-06:season&direct=true&one_way=false&no_visa=true&schengen=true&need_visa=true&locale=ru&min_trip_duration_in_days=30&max_trip_duration_in_days=60"
response = requests.request("GET", url)

print(response.text)
# Out:
# [{"value":45258.0,"ttl":1617609231,"trip_class":0,"show_to_affiliates":false,"return_date":"2021-07-20","origin":"NYC","number_of_changes":1,"gate":"TrustFares","found_at":"2021-04-03T07:53:51","distance":0,"destination":"CAI","depart_date":"2021-06-20","created_at":1617436431,"airline":"AZ","actual":true},{"value":47301.0,"ttl":1617465299,"trip_class":0,"show_to_affiliates":false,"return_date":"2021-07-14","origin":"NYC","number_of_changes":1,"gate":"Kiwi.com","found_at":"2021-04-01T15:54:59","distance":0,"destination":"TIA","depart_date":"2021-06-14","created_at":1617292499,"airline":"BF","actual":true},{"value":37124.0,"ttl":1617718161,"trip_class":0,"show_to_affiliates":false,"return_date":"2021-05-15","origin":"NYC","number_of_changes":1,"gate":"MyHolidays","found_at":"2021-04-04T14:09:21","distance":0,"destination":"SCL","depart_date":"2021-04-15","created_at":1617545361,"airline":"AA","actual":true},{"value":51020.0,"ttl":1617726436,"trip_class":0,"show_to_affiliates":false,"r
# ...

# %% [markdown]
# # Price Map: supported routes

# %%
url = "http://map.aviasales.ru/supported_directions.json?origin_iata=SFO&one_way=false&locale=en"
response = requests.request("GET", url)

print(response.text)
# Out:
# {"origin":{"iata":"SFO","name":"San Francisco","country":"US","coordinates":[-122.4194155,37.7749295]},"directions":[{"direct":false,"iata":"SAB","name":"Saba","country":"BQ","country_name":"Caribbean Netherlands","coordinates":[-63.216667,17.65],"weight":0,"weather":{"weathertype":null,"temp_min":null,"temp_max":null}},{"direct":false,"iata":"YZY","name":"Zhangye","country":"CN","country_name":"China","coordinates":[100.660835,38.8075],"weight":0,"weather":{"weathertype":null,"temp_min":null,"temp_max":null}},{"direct":false,"iata":"CYB","name":"Cayman Brac Island","country":"KY","country_name":"Cayman Islands","coordinates":[-79.87941,19.690191],"weight":0,"weather":{"weathertype":null,"temp_min":null,"temp_max":null}},{"direct":false,"iata":"MMK","name":"Murmansk","country":"RU","country_name":"Russia","coordinates":[32.759155,68.785095],"weight":0,"weather":{"weathertype":null,"temp_min":null,"temp_max":null}},{"direct":false,"iata":"LAE","name":"Lae","country":"PG","country_name
# ...

# %% [markdown]
# # Price calendar API

# %%
#Prices calendar API
url= "http://min-prices.aviasales.ru/calendar_preload?origin=NYC&destination=SFO&depart_date=2021-04-06&one_way=false"
response = requests.request("GET", url)

print(response.text)
# Out:
# {"errors":{},"current_depart_date_prices":[{"value":19970.0,"trip_class":0,"show_to_affiliates":false,"return_date":"2021-04-12","origin":"NYC","number_of_changes":1,"gate":"Kiwi.com","found_at":"2021-03-31T05:09:39","distance":4134,"destination":"SFO","depart_date":"2021-04-06","actual":true},{"value":19758.0,"trip_class":0,"show_to_affiliates":false,"return_date":"2021-04-13","origin":"NYC","number_of_changes":2,"gate":"Kissandfly.com","found_at":"2021-04-01T21:47:31","distance":4134,"destination":"SFO","depart_date":"2021-04-06","actual":true},{"value":18427.0,"trip_class":0,"show_to_affiliates":false,"return_date":"2021-04-20","origin":"NYC","number_of_changes":1,"gate":"Kiwi.com","found_at":"2021-03-30T11:51:19","distance":4134,"destination":"SFO","depart_date":"2021-04-06","actual":true}],"best_prices":[{"value":20014.0,"trip_class":0,"show_to_affiliates":false,"return_date":"2022-02-21","origin":"NYC","number_of_changes":0,"gate":"MyHolidays","found_at":"2021-04-03T20:28:04","
# ...

# %% [markdown]
# # Travel insights with Travelpayouts Data API

# %% [markdown]
# ### Flight Price History

# %%
#Flight Price History
url="http://api.travelpayouts.com/v2/prices/latest?currency=usd&period_type=year&page=10&limit=500&show_to_affiliates=true&sorting=price&trip_class=0&token=ed625cf473b6ec639bfc3083a9d0d414"
response = requests.request("GET", url)

print(response.text)
# Out:
# {"success":true,"data":[{"value":81,"trip_class":0,"show_to_affiliates":true,"origin":"MYR","destination":"NYC","gate":"Gotogate","depart_date":"2021-05-14","return_date":"2021-05-16","number_of_changes":0,"found_at":"2021-04-02T14:13:04","duration":223,"distance":893,"actual":true},{"value":81,"trip_class":0,"show_to_affiliates":true,"origin":"KOJ","destination":"TYO","gate":"Lucky2Go","depart_date":"2021-05-08","return_date":"2021-05-09","number_of_changes":0,"found_at":"2021-04-03T02:16:14","duration":240,"distance":936,"actual":true},{"value":81,"trip_class":0,"show_to_affiliates":true,"origin":"UFA","destination":"STW","gate":"Aviakassa","depart_date":"2021-10-13","return_date":"2021-10-20","number_of_changes":1,"found_at":"2021-04-01T16:37:46","duration":810,"distance":1424,"actual":true},{"value":81,"trip_class":0,"show_to_affiliates":true,"origin":"IEV","destination":"AYT","gate":"Kiwi.com","depart_date":"2021-04-06","return_date":"2021-04-20","number_of_changes":1,"found_at"
# ...

# %% [markdown]
# ### The calendar of prices for a month

# %%
#The calendar of prices for a month
url = "http://api.travelpayouts.com/v2/prices/month-matrix?currency=usd&origin=NYC&destination=SFO&show_to_affiliates=true&token=ed625cf473b6ec639bfc3083a9d0d414"
response = requests.request("GET", url)

print(response.text)
# Out:
# {"success":true,"data":[{"value":100,"trip_class":0,"show_to_affiliates":true,"origin":"NYC","destination":"SFO","gate":"Kiwi.com","depart_date":"2021-05-06","return_date":"","number_of_changes":2,"found_at":"2021-04-05T00:28:33","duration":2059,"distance":4134,"actual":true},{"value":77,"trip_class":0,"show_to_affiliates":true,"origin":"NYC","destination":"SFO","gate":"Kiwi.com","depart_date":"2021-05-03","return_date":"","number_of_changes":2,"found_at":"2021-04-03T04:55:40","duration":2286,"distance":4134,"actual":true},{"value":121,"trip_class":0,"show_to_affiliates":true,"origin":"NYC","destination":"SFO","gate":"Tickets.ru","depart_date":"2021-05-06","return_date":"","number_of_changes":3,"found_at":"2021-04-05T00:28:33","duration":2286,"distance":4134,"actual":true},{"value":103,"trip_class":0,"show_to_affiliates":true,"origin":"NYC","destination":"SFO","gate":"Kiwi.com","depart_date":"2021-05-01","return_date":"","number_of_changes":2,"found_at":"2021-03-31T01:47:20","duratio
# ...

# %% [markdown]
# ### The prices for the alternative directions

# %%
#The prices for the alternative directions
url = "http://api.travelpayouts.com/v2/prices/nearest-places-matrix?currency=usd&origin=NYC&destination=SFO&show_to_affiliates=true&token=ed625cf473b6ec639bfc3083a9d0d414"
response = requests.request("GET", url)

print(response.text)
# Out:
# {"success":true,"data":{"prices":[{"value":339,"trip_class":0,"show_to_affiliates":true,"origin":"NYC","destination":"OAK","gate":"MyHolidays","depart_date":"2021-04-11","return_date":"2021-04-22","number_of_changes":1,"found_at":"2021-04-05T04:46:14","duration":1300,"distance":4120,"actual":true},{"value":266,"trip_class":0,"show_to_affiliates":true,"origin":"NYC","destination":"SFO","gate":"MyHolidays","depart_date":"2021-04-06","return_date":"2021-04-20","number_of_changes":0,"found_at":"2021-03-30T11:51:19","duration":733,"distance":4133,"actual":true},{"value":241,"trip_class":0,"show_to_affiliates":true,"origin":"NYC","destination":"SFO","gate":"Kiwi.com","depart_date":"2021-04-06","return_date":"2021-04-20","number_of_changes":1,"found_at":"2021-03-30T11:51:19","duration":1538,"distance":4133,"actual":true},{"value":292,"trip_class":0,"show_to_affiliates":true,"origin":"NYC","destination":"SFO","gate":"Kissandfly.com","depart_date":"2021-04-11","return_date":"2021-04-22","numb
# ...

# %% [markdown]
# ### Cheapest Tickets

# %%
#Cheapest Tickets
url = "http://api.travelpayouts.com/v1/prices/cheap?origin=SFO&destination=NYC&depart_date=2021-04&return_date=2021-05&token=ed625cf473b6ec639bfc3083a9d0d414"
response = requests.request("GET", url)

print(response.text)
# Out:
# {"success":true,"data":{"NYC":{"0":{"price":15231,"airline":"UA","flight_number":2304,"departure_at":"2021-05-14T15:45:00Z","return_at":"2021-05-16T18:38:00Z","expires_at":"2021-04-07T00:11:05Z"},"1":{"price":15694,"airline":"AS","flight_number":1024,"departure_at":"2021-05-14T20:25:00Z","return_at":"2021-05-17T16:56:00Z","expires_at":"2021-04-06T00:20:00Z"},"2":{"price":12628,"airline":"F9","flight_number":664,"departure_at":"2021-04-27T20:25:00Z","return_at":"2021-05-14T19:06:00Z","expires_at":"2021-04-06T23:37:12Z"},"3":{"price":15034,"airline":"F9","flight_number":2790,"departure_at":"2021-05-14T22:45:00Z","return_at":"2021-05-18T04:04:00Z","expires_at":"2021-04-06T00:20:00Z"},"4":{"price":19719,"airline":"F9","flight_number":2078,"departure_at":"2021-05-12T17:54:00Z","return_at":"2021-05-20T06:58:00Z","expires_at":"2021-04-06T00:47:59Z"}}},"error":"","currency":"rub"}

# %% [markdown]
# ### Cheapest tickets grouped by month

# %%
#Cheapest tickets grouped by month
url = "http://api.travelpayouts.com/v1/prices/monthly?currency=INR&origin=SFO&destination=NYC&token=ed625cf473b6ec639bfc3083a9d0d414"
response = requests.request("GET", url)

print(response.text)
# Out:
# {"success":true,"data":{"2021-04":{"origin":"SFO","destination":"NYC","price":12155,"transfers":2,"airline":"F9","flight_number":664,"departure_at":"2021-04-27T20:25:00Z","return_at":"2021-05-14T19:06:00Z","expires_at":"2021-04-07T23:51:52Z"},"2021-05":{"origin":"SFO","destination":"NYC","price":14025,"transfers":2,"airline":"F9","flight_number":664,"departure_at":"2021-05-06T20:05:00Z","return_at":"2021-05-10T19:06:00Z","expires_at":"2021-04-05T23:49:43Z"},"2021-06":{"origin":"SFO","destination":"NYC","price":18458,"transfers":0,"airline":"B6","flight_number":482,"departure_at":"2021-06-20T04:10:00Z","return_at":"2021-06-27T02:56:00Z","expires_at":"2021-04-07T20:59:13Z"},"2021-07":{"origin":"SFO","destination":"NYC","price":18064,"transfers":1,"airline":"AA","flight_number":166,"departure_at":"2021-07-08T22:11:00Z","return_at":"2021-07-13T01:22:00Z","expires_at":"2021-04-05T17:56:36Z"},"2021-09":{"origin":"SFO","destination":"NYC","price":11323,"transfers":1,"airline":"NK","flight_n
# ...

# %% [markdown]
# ### Non-stop tickets

# %%
#Non-stop tickets
url = "http://api.travelpayouts.com/v1/prices/direct?origin=SFO&destination=NYC&depart_date=2021-04&return_date=2021-05&token=ed625cf473b6ec639bfc3083a9d0d414"
response = requests.request("GET", url)

print(response.text)
# Out:
# {"success":true,"data":{"NYC":{"0":{"price":15231,"airline":"UA","flight_number":2304,"departure_at":"2021-05-14T15:45:00Z","return_at":"2021-05-16T18:38:00Z","expires_at":"2021-04-07T00:11:05Z"}}},"error":"","currency":"rub"}

# %% [markdown]
# ### Flight Price Trends

# %%
#Flight Price Trends
url = "http://api.travelpayouts.com/v1/prices/calendar?depart_date=2021-04&origin=SFO&destination=NYC&calendar_type=departure_date&token=ed625cf473b6ec639bfc3083a9d0d414"
response = requests.request("GET", url)

print(response.text)
# Out:
# {"success":true,"data":{"2021-04-06":{"origin":"SFO","destination":"NYC","price":30962,"transfers":2,"airline":"AA","flight_number":234,"departure_at":"2021-04-06T14:30:00Z","return_at":"2021-04-12T17:49:00Z","expires_at":"2021-04-06T14:30:00Z"},"2021-04-07":{"origin":"SFO","destination":"NYC","price":24078,"transfers":1,"airline":"AA","flight_number":651,"departure_at":"2021-04-07T18:21:00Z","return_at":"2021-04-09T21:06:00Z","expires_at":"2021-04-07T18:21:00Z"},"2021-04-10":{"origin":"SFO","destination":"NYC","price":21924,"transfers":1,"airline":"AA","flight_number":2614,"departure_at":"2021-04-10T14:19:00Z","return_at":"2021-04-18T01:14:00Z","expires_at":"2021-04-06T16:57:23Z"},"2021-04-12":{"origin":"SFO","destination":"NYC","price":21937,"transfers":0,"airline":"AA","flight_number":276,"departure_at":"2021-04-12T05:20:00Z","return_at":"2021-04-14T04:19:00Z","expires_at":"2021-04-08T05:08:55Z"},"2021-04-13":{"origin":"SFO","destination":"NYC","price":18421,"transfers":1,"airline
# ...

# %% [markdown]
# ### Popular airline routes

# %%
#Popular airline routes
url = "http://api.travelpayouts.com/v1/airline-directions?airline_code=SU&limit=500&token=ed625cf473b6ec639bfc3083a9d0d414"
response = requests.request("GET", url)

print(response.text)
# Out:
# {"success":true,"data":{"SVO-LED":34156097,"LED-SVO":33165245,"SVO-AER":7836304,"AER-SVO":7087935,"SVO-SVX":4153305,"SVX-SVO":3484375,"SVO-IST":3439666,"IST-SVO":3336777,"SVO-KRR":2802423,"SVO-KZN":2699142,"KRR-SVO":2690595,"KZN-SVO":2282077,"SVO-KGD":2022146,"SVO-SIP":1973307,"SIP-SVO":1915864,"KGD-SVO":1797292,"SVO-KUF":1735773,"KUF-SVO":1648785,"UFA-SVO":1436575,"SVO-ROV":1404252,"ROV-SVO":1389647,"SVO-MRV":1301004,"SVO-OVB":1274711,"SVO-UFA":1202907,"MRV-SVO":1147765,"OVB-SVO":1085317,"SVO-AAQ":871896,"SVO-KJA":745716,"AER-SIP":710940,"AAQ-SVO":674362,"LHR-SVO":630989,"SVO-LHR":628420,"KJA-SVO":603668,"SVO-AYT":552999,"SIP-AER":516645,"AYT-SVO":458040,"SVO-IKT":448372,"PEE-SVO":442795,"SVO-PEE":422238,"FRA-SVO":396630,"IKT-SVO":380834,"SVO-OMS":373628,"SVO-FRA":370855,"OMS-SVO":319216,"AMS-SVO":292990,"VIE-SVO":285614,"SVO-VVO":282084,"CDG-SVO":281838,"VVO-SVO":280025,"SVO-VIE":256214,"SVO-GDZ":242424,"SVO-GOJ":228437,"SVO-VOG":221162,"SVO-AMS":211571,"SVO-KHV":205661,"SVO-REN":2
# ...

# %% [markdown]
# ### The calendar of prices for a week

# %%
#The calendar of prices for a week
url = "http://api.travelpayouts.com/v2/prices/week-matrix?currency=usd&origin=SFO&destination=NYC&show_to_affiliates=true&depart_date=2021-04-06&return_date=2021-04-13&token=ed625cf473b6ec639bfc3083a9d0d414"
response = requests.request("GET", url)

print(response.text)
# Out:
# {"success":true,"data":[{"value":480,"trip_class":0,"show_to_affiliates":true,"origin":"SFO","destination":"NYC","gate":"TrustFares","depart_date":"2021-04-05","return_date":"2021-04-11","number_of_changes":0,"found_at":"2021-04-03T06:26:16","actual":true},{"value":484,"trip_class":0,"show_to_affiliates":true,"origin":"SFO","destination":"NYC","gate":"Vayama","depart_date":"2021-04-05","return_date":"2021-04-11","number_of_changes":1,"found_at":"2021-04-03T06:26:16","actual":true},{"value":511,"trip_class":0,"show_to_affiliates":true,"origin":"SFO","destination":"NYC","gate":"Trip.com","depart_date":"2021-04-05","return_date":"2021-04-11","number_of_changes":2,"found_at":"2021-04-03T06:26:16","actual":true},{"value":431,"trip_class":0,"show_to_affiliates":true,"origin":"SFO","destination":"NYC","gate":"Kiwi.com","depart_date":"2021-04-06","return_date":"2021-04-10","number_of_changes":0,"found_at":"2021-04-04T15:43:52","actual":true},{"value":478,"trip_class":0,"show_to_affiliates":t
# ...

# %% [markdown]
# ### The popular destinations

# %%
#The popular destinations
url = "http://api.travelpayouts.com/v1/city-directions?origin=SFO&currency=usd&token=ed625cf473b6ec639bfc3083a9d0d414"
response = requests.request("GET", url)

print(response.text)
# Out:
# {"success":true,"data":{"CUN":{"origin":"SFO","destination":"CUN","price":261,"transfers":1,"airline":"F9","flight_number":664,"departure_at":"2021-06-10T19:30:00Z","return_at":"2021-06-16T06:58:00Z","expires_at":"2021-04-06T22:41:55Z"},"HNL":{"origin":"SFO","destination":"HNL","price":274,"transfers":0,"airline":"UA","flight_number":1175,"departure_at":"2021-05-03T16:05:00Z","return_at":"2021-06-04T05:57:00Z","expires_at":"2021-04-08T05:25:00Z"},"IST":{"origin":"SFO","destination":"IST","price":588,"transfers":1,"airline":"BA","flight_number":5526,"departure_at":"2021-05-01T02:15:00Z","return_at":"2021-05-10T03:55:00Z","expires_at":"2021-04-05T15:21:31Z"},"KBL":{"origin":"SFO","destination":"KBL","price":979,"transfers":1,"airline":"TK","flight_number":80,"departure_at":"2021-06-02T01:10:00Z","return_at":"2021-07-02T20:15:00Z","expires_at":"2021-04-06T02:49:20Z"},"LAS":{"origin":"SFO","destination":"LAS","price":43,"transfers":0,"airline":"F9","flight_number":2076,"departure_at":"20
# ...

# %% [markdown]
# ### Flights Special Offers

# %%
#Flights Special Offers
url = "http://api.travelpayouts.com/v2/prices/special-offers?lan=en&token=ed625cf473b6ec639bfc3083a9d0d414"
response = requests.request("GET", url)

print(response.text)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <offers>
#   <offer airline="Smartavia" airline_code="5N" title="Из Архангельска в Крым от 5800 рублей! Специальное предложение от авиакомпании Smartavia" id="47020" href="https://www.aviasales.ru/offers/iz-arhangelska-v-krym-ot-5800-rublei-spetsialnoe-predlozhenie-ot-aviakompanii-smartavia" sale_date_begin="1617321600" sale_date_end="1619308800" flight_date_begin="1617321600" flight_date_end="1630368000" link="https://hydra.aviasales.ru/adaptors/special_offer?iata=5N&amp;utm_source=www&amp;locale=ru&amp;url=">
#     <description/>
# ...
